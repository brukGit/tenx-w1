# %% [markdown]
# # Publisher Analysis

# %% [markdown]
# ## Import libraries and modules

# %%
import pandas as pd
import numpy as np
import sys
import os
# Define the path to the src directory
src_dir = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
sys.path.insert(0, src_dir)

# Delete the eda and data_loader modules if they exist
if 'publisher_analysis' in sys.modules:
    del sys.modules['publisher_analysis']
if 'data_loader' in sys.modules:
    del sys.modules['data_loader']

from publisher_analysis import PublisherAnalysis
from data_loader import DataLoader

# %% [markdown]
# ## Load Cleaned Data

# %%
# Load and clean data
data_loader = DataLoader("../data/raw_analyst_ratings/raw_analyst_ratings.csv")
df = data_loader.load_data()
df = data_loader.clean_data(df)

# Create PublisherAnalysis object
pa = PublisherAnalysis(df)

# %% [markdown]
# ## Perform Publisher Analysis

# %% [markdown]
# ### Most Active Publishers

# %%
# Obtain publisher_counts
publisher_counts = pa.most_active_publishers()
print("Publisher counts:")
print(publisher_counts)
# Out:
# Publisher counts:
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: publisher, Length: 1034, dtype: int64

# %% [markdown]
# ### Publisher domains(urls)

# %%
# Plot and count publisher domains
domain_counts = pa.analyze_publisher_domains()
print("\nPublisher Domain Counts:")
print(domain_counts)
# Out:
# Publisher Domain Counts:
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: domain, dtype: int64

# %% [markdown]
# ### News type per publisher

# %%
# Plot and count news type per publisher
news_type_counts = pa.analyze_news_type()
print("\nNews Type Counts:")
print(news_type_counts)
# Out:
# Training the model...
# Model accuracy: 0.00
# News Type Counts:
# news_type                                   Health  Politics  Sports  \
# publisher
# Andy@andyswan.com                              0.0       0.0     0.0
# adam@eosdetroit.io                             0.0       0.0     0.0
# aefimoff@benzinga.com                          0.0       0.0     0.0
# andrew@tothetick.com                           0.0       0.0     0.0
# andrewbeghou@benzinga.com                      0.0       0.0     0.0
# bret.kenwell@benzinga.com                      2.0       4.0     0.0
# dhiraj.surapaneni@benzinga.com                 0.0       0.0     0.0
# javierhasseandericterbush@benzinga.com         0.0       0.0     0.0
# jennifer25anthony@gmail.com                    0.0       0.0     0.0
# kiana@investdiva.com                           0.0       0.0     0.0
# luke@benzinga.com                             50.0     116.0    44.0
# newsdesk+benzingastaffwriter3@benzinga.com     0.0       0.0     0.0
# official@stockmetrix.net                       0.0       0.0     0.0
# richa28dhand@gmail.com                         0.0       0.0     0.0
# shivdeep@benzinga.com                          0.0       0.0     0.0
# vic@forextraininggroup.com                     0.0       0.0     0.0
# vishwanath@benzinga.com                       11.0       0.0     0.0
# vivek.proactive@gmail.com                      1.0       0.0     0.0
#
# news_type                                   Technology
# publisher
# Andy@andyswan.com                                  5.0
# adam@eosdetroit.io                                 1.0
# aefimoff@benzinga.com                              3.0
# andrew@tothetick.com                               2.0
# andrewbeghou@benzinga.com                          2.0
# bret.kenwell@benzinga.com                        890.0
# dhiraj.surapaneni@benzinga.com                     1.0
# javierhasseandericterbush@benzinga.com             1.0
# jennifer25anthony@gmail.com                        2.0
# kiana@investdiva.com                               2.0
# luke@benzinga.com                               4988.0
# newsdesk+benzingastaffwriter3@benzinga.com         3.0
# official@stockmetrix.net                           1.0
# richa28dhand@gmail.com                            17.0
# shivdeep@benzinga.com                              3.0
# vic@forextraininggroup.com                         1.0
# vishwanath@benzinga.com                         1819.0
# vivek.proactive@gmail.com                        119.0

# %% [markdown]
# ### News Focus of top 5 publishers

# %%
# Plot news focus for each publisher
print("Analyzing news focus for top 5 publishers...")
news_focus = pa.analyze_top_publishers_news_types()
print(news_focus)
# Out:
# Analyzing news focus for top 5 publishers...
# {'luke@benzinga.com': {'Politics': 0.022316275490573297, 'Economy': 0.0, 'Health': 0.009619084263178146, 'Technology': 0.9595998460946518, 'Sports': 0.008464794151596768, 'Other': 0.0}, 'vishwanath@benzinga.com': {'Politics': 0.0, 'Economy': 0.0, 'Health': 0.006010928961748634, 'Technology': 0.9939890710382514, 'Sports': 0.0, 'Other': 0.0}, 'bret.kenwell@benzinga.com': {'Politics': 0.004464285714285714, 'Economy': 0.0, 'Health': 0.002232142857142857, 'Technology': 0.9933035714285714, 'Sports': 0.0, 'Other': 0.0}, 'vivek.proactive@gmail.com': {'Politics': 0.0, 'Economy': 0.0, 'Health': 0.008333333333333333, 'Technology': 0.9916666666666667, 'Sports': 0.0, 'Other': 0.0}, 'richa28dhand@gmail.com': {'Politics': 0.0, 'Economy': 0.0, 'Health': 0.0, 'Technology': 1.0, 'Sports': 0.0, 'Other': 0.0}}
